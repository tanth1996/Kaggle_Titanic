# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import sklearn
from sklearn.model_selection import cross_val_score, ShuffleSplit
import graphviz

# %%
# Peek Test Data
TestDf = pd.read_csv('test.csv') # passenger dataframe
TestDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# Read data
PassDf = pd.read_csv('train.csv') # passenger dataframe
PassDf.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
PassDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Age and Cabin are missing values

# %%
# Ensure Passenger IDs are not duplicated
PassDf['PassengerId'].is_unique
# Out:
# True

# %%
# Set new index as Passenger ID
PassDf.set_index('PassengerId', inplace=True)
PassDf
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Replace 'Sex' column with one-hot variables
PassDf = PassDf.join(pd.get_dummies(PassDf['Sex']))
PassDf.drop(columns='Sex', inplace=True)
PassDf
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 3                                       Heikkinen, Miss. Laina  26.0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 5                                     Allen, Mr. William Henry  35.0      0
# ...                                                        ...   ...    ...
# ...

# %%
# Drop irrelevant label
PassDf.rename(columns={'female':'IsFemale'}, inplace=True)
PassDf.drop(columns=['male'], inplace=True)

# %%
# Get numeric columns
PassDf_num = PassDf.select_dtypes(include=np.number)
PassDf_num
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  IsFemale
# PassengerId
# 1                   0       3  22.0      1      0   7.2500         0
# 2                   1       1  38.0      1      0  71.2833         1
# 3                   1       3  26.0      0      0   7.9250         1
# 4                   1       1  35.0      1      0  53.1000         1
# 5                   0       3  35.0      0      0   8.0500         0
# ...               ...     ...   ...    ...    ...      ...       ...
# 887                 0       2  27.0      0      0  13.0000         0
# 888                 1       1  19.0      0      0  30.0000         1
# 889                 0       3   NaN      1      2  23.4500         1
# 890                 1       1  26.0      0      0  30.0000         0
# 891                 0       3  32.0      0      0   7.7500         0
#
# [891 rows x 7 columns]

# %%
# Plot distributions of numeric variables
for Column in PassDf_num:
    fig, ax = plt.subplots(1,1,figsize=(10,5))
    hist, bins, patches = ax.hist(PassDf_num[column], align='mid', rwidth=0.9)
    ax.set_xticks(bins)
    ax.set_title('Histogram of ' + Column)
    ax.grid()
    plt.show()

# %%
# Plot separate histograms for survivors and fatalities
for Feature in PassDf_num.drop(columns='Survived').columns:
    FacetGrid = sns.FacetGrid(PassDf_num, col='Survived')
    FacetGrid.map(plt.hist, Feature)

# %%
# Pairwise plot
PairPlot = sns.pairplot(PassDf_num, hue='Survived', kind='reg', diag_kind='hist')
# Out:
# C:\Users\tanth\Anaconda3\envs\maclearning\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\tanth\Anaconda3\envs\maclearning\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Split data into training and validation
from sklearn.model_selection import train_test_split
Features = pass_df_num.drop(columns=['Survived'])
Label = pass_df_num[['Survived']]
TrainFeat, TestFeat, TrainLabel, TestLabel = train_test_split(Features, Label, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# Standardise appropriate columns
Standardiser = StandardScaler(copy=True, with_mean=True, with_std=True)
StdFeatures = ['Age', "Fare"]
ColStandardiser = ColumnTransformer([('Standardiser', Standardiser, StdFeatures)], remainder='passthrough')
ColStandardiser.fit(TrainFeat)

# Fill missing age values
Imputer = SimpleImputer(strategy='mean')
Imputer.fit(TrainFeat)
PrepPipeline = Pipeline([('ColStandardiser', ColStandardiser), ('Imputer', Imputer)])

# %% [markdown]
# #### Function to standardise columns and impute missing values

# %%
def StandardiseImpute(Features, StdFeatures, ImputeFeatures):
    # Standardise appropriate columns
    Standardiser = StandardScaler(copy=True, with_mean=True, with_std=True)
    StdImpFeatures = Features.copy()
    StdImpFeatures[StdFeatures] = Standardiser.fit_transform(Features[StdFeatures])

    # Fill missing values
    for Feature in ImputeFeatures:
        StdImpFeatures.fillna(value={Feature : StdImpFeatures[Feature].mean()}, inplace=True)
    return StdImpFeatures

# %%
StdFeatures = ['Age', 'Fare']
ImputeFeatures = ['Age', 'Fare']
PassDf_num_n = StandardiseImpute(PassDf_num, StdFeatures, ImputeFeatures)
PassDf_num_n
# Out:
#              Survived  Pclass           Age  SibSp  Parch      Fare  IsFemale
# PassengerId
# 1                   0       3 -5.303766e-01      1      0 -0.502445         0
# 2                   1       1  5.718310e-01      1      0  0.786845         1
# 3                   1       3 -2.548247e-01      0      0 -0.488854         1
# 4                   1       1  3.651671e-01      1      0  0.420730         1
# 5                   0       3  3.651671e-01      0      0 -0.486337         0
# ...               ...     ...           ...    ...    ...       ...       ...
# 887                 0       2 -1.859368e-01      0      0 -0.386671         0
# 888                 1       1 -7.370406e-01      0      0 -0.044381         1
# 889                 0       3  2.388379e-16      1      2 -0.176263         1
# 890                 1       1 -2.548247e-01      0      0 -0.044381         0
# 891                 0       3  1.585031e-01      0      0 -0.492378         0
#
# ...

# %%
# Check correlation matrix
FeatCorr = PassDf_num_n.corr()
fig, ax = plt.subplots(1,1,figsize=(10,10))
sns.heatmap(FeatCorr, annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# Peek most correlated variables
FeatCorr['Survived'].abs().sort_values(ascending=False)
# Out:
# Survived    1.000000
# IsFemale    0.543351
# Pclass      0.338481
# Fare        0.257307
# Parch       0.081629
# Age         0.069809
# SibSp       0.035322
# Name: Survived, dtype: float64

# %%
# Perform PCA
from sklearn.decomposition import PCA
PCA_Model = PCA(n_components=3)

# Fit on most correlated features
PCA_Feat = ['IsFemale','Pclass','Fare']
PCA_Model.fit(PassDf_num_n.loc[:,PCA_Feat])
print('Explained variances: ', PCA_Model.explained_variance_ratio_)
print('Components: ', PCA_Model.components_)

# Cumulative explained variance
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
xticks = range(1,len(PCA_Model.explained_variance_ratio_) + 1)
ax.plot(xticks, np.cumsum(PCA_Model.explained_variance_ratio_))
ax.set_xticks(xticks)
ax.grid()
ax.set_title('Cumulative explained variance of Principal Components')
ax.set_xlabel('No. of Principal Components')
plt.show()
# Out:
# Explained variances:  [0.69644963 0.19012962 0.11342075]
# Components:  [[ 0.09072637 -0.5833826   0.80711428]
#  [ 0.0566154   0.81216742  0.58067097]
#  [-0.99426527 -0.00698707  0.10671344]]

# %%
# Transform data into Principal Components
PassDf_PC = pd.DataFrame(PCA_Model.transform(PassDf_num_n.loc[:,PCA_Feat]))
PassDf_PC.set_index(pass_df.index, inplace=True)
PassDf_PC.rename(columns=lambda x: 'PC' + str(int(x)+1), inplace=True)
PassDf_PC
# Out:
#                   PC1       PC2       PC3
# PassengerId
# 1           -0.840830  0.249791  0.291944
# 2            1.457266 -0.569275 -0.550763
# 3           -0.739134  0.314298 -0.700871
# 4            1.161770 -0.781867 -0.589832
# 5           -0.827829  0.259144  0.293663
# ...               ...       ...       ...
# 887         -0.164004 -0.495149  0.311286
# 888          0.786372 -1.051944 -0.639466
# 889         -0.486838  0.495811 -0.667513
# 890          0.695645 -1.108559  0.354800
# 891         -0.832705  0.255637  0.293018
#
# [891 rows x 3 columns]

# %%
# Join PCs with main dataframe
PassDf_PC = PassDf_num_n.join(PassDf_PC)
PassDf_PC
# Out:
#              Survived  Pclass           Age  SibSp  Parch      Fare  IsFemale  \
# PassengerId
# 1                   0       3 -5.303766e-01      1      0 -0.502445         0
# 2                   1       1  5.718310e-01      1      0  0.786845         1
# 3                   1       3 -2.548247e-01      0      0 -0.488854         1
# 4                   1       1  3.651671e-01      1      0  0.420730         1
# 5                   0       3  3.651671e-01      0      0 -0.486337         0
# ...               ...     ...           ...    ...    ...       ...       ...
# 887                 0       2 -1.859368e-01      0      0 -0.386671         0
# 888                 1       1 -7.370406e-01      0      0 -0.044381         1
# 889                 0       3  2.388379e-16      1      2 -0.176263         1
# 890                 1       1 -2.548247e-01      0      0 -0.044381         0
# 891                 0       3  1.585031e-01      0      0 -0.492378         0
#
# ...

# %%
# Plot PC components
cmap = cm.viridis(np.linspace(0,1,2))

fig, ax = plt.subplots(1,1, figsize=(10,5))
ax.scatter(PassDf_PC['PC1'], PassDf_PC['PC2'], c=cmap[PassDf_PC['Survived']])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
plt.show()
fig, ax = plt.subplots(1,1, figsize=(10,5))
ax.scatter(PassDf_PC['PC1'], PassDf_PC['PC3'], c=cmap[PassDf_PC['Survived']])
ax.set_xlabel('PC1')
ax.set_ylabel('PC3')
plt.show()
fig, ax = plt.subplots(1,1, figsize=(10,5))
ax.scatter(PassDf_PC['PC2'], PassDf_PC['PC3'], c=cmap[PassDf_PC['Survived']])
ax.set_xlabel('PC2')
ax.set_ylabel('PC3')
plt.show()

# %% [markdown]
# #### Function to concatenate PCs as features to a dataframe

# %%
def JoinPCs(Features, PCA_Features, PCA_Model):
    Features_PCA = pd.DataFrame(PCA_Model.transform(Features[PCA_features]))
    Features_PCA.set_index(Features.index, inplace=True)
    Features_PCA.rename(columns=lambda x: 'PC' + str(int(x)+1), inplace=True)
    Features_PCA = Features.join(Features_PCA)
    return Features_PCA

# %%
# Split data into training and validation
from sklearn.model_selection import train_test_split
Features = PassDf_num_n.drop(columns=['Survived'])
Label = PassDf_num_n[['Survived']]
TrainFeat, TestFeat, TrainLabel, TestLabel = train_test_split(Features, Label, test_size=0.2, random_state=62)

# %%
# Standardise and impute missing values and attach PCs
TrainFeat = StandardiseImpute(TrainFeat, ['Age', 'Fare'], ['Age'])
TrainFeat = JoinPCs(TrainFeat, ['IsFemale','Pclass','Fare'], PCA_Model)
TestFeat = StandardiseImpute(TestFeat, ['Age', 'Fare'], ['Age'])
TestFeat = JoinPCs(TestFeat, ['IsFemale','Pclass','Fare'], PCA_Model)

# %%
# Check correlation matrix
FeatCorr = TrainFeat.join(TrainLabel).corr()
fig, ax = plt.subplots(1,1,figsize=(10,10))
sns.heatmap(FeatCorr, annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# Peek most correlated variables
FeatCorr['Survived'].abs().sort_values(ascending=False)
# Out:
# Survived    1.000000
# IsFemale    0.544788
# PC3         0.490353
# PC1         0.347747
# Pclass      0.339791
# Fare        0.267431
# PC2         0.100333
# Parch       0.085991
# Age         0.059210
# SibSp       0.033779
# Name: Survived, dtype: float64

# %% [markdown]
# #### Function to check accuracy of model prediction for training and test data

# %%
def PlotConfusionMatrix(TrueLabels, PredictedLabels):
    # Plot confusion matrix
    Confusion = sklearn.metrics.confusion_matrix(TrueLabels, PredictedLabels)
    fig, ax = plt.subplots(1,2,figsize=(10,5))
    sns.heatmap(Confusion, annot=True, ax=ax[0])
    bottom, top = ax[0].get_ylim()
    ax[0].set_ylim(bottom + 0.5, top - 0.5)
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    
    # Normalised confusion matrix
    Confusion_n = Confusion/Confusion.sum(axis=1)[:,np.newaxis]
    sns.heatmap(Confusion_n, annot=True, ax=ax[1])
    bottom, top = ax[1].get_ylim()
    ax[1].set_ylim(bottom + 0.5, top - 0.5)
    ax[1].set_xlabel('Predicted')
    ax[1].set_ylabel('Actual')
    plt.show()

# %%
def PredictionResults(Model, TrainFeatures, TrainLabel, TestFeatures, TestLabel):
    # Check decision tree accuracy on training set
    TestPredict = Model.predict(TrainFeatures).round()
    TestCompare = TestPredict == TrainLabel['Survived']
    Accuracy =  TestCompare.sum()/TestCompare.size
    print('Model accuracy on training: ', Accuracy)
    
    PlotConfusionMatrix(TrainLabel, TestPredict)

    # Check decision tree accuracy on test set
    TestPredict = Model.predict(TestFeatures).round()
    TestCompare = TestPredict == TestLabel['Survived']
    Accuracy =  TestCompare.sum()/TestCompare.size
    print('Model accuracy on test: ', Accuracy)

    PlotConfusionMatrix(TestLabel, TestPredict)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LogReg = LogisticRegression(penalty='l2', fit_intercept=True, solver='saga')
Features = ['IsFemale', 'Pclass', 'Fare', 'Parch', 'Age', 'SibSp']
LogReg.fit(TrainFeat[Features], TrainLabel['Survived'].ravel())
PredictionResults(LogReg, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.8075842696629213
# Model accuracy on test:  0.7877094972067039

# %%
LogReg_PCA = LogisticRegression(penalty='l2', fit_intercept=True, solver='saga', max_iter=1000)
LogReg_PCA.fit(TrainFeat, TrainLabel['Survived'].ravel())
PredictionResults(LogReg_PCA, TrainFeat, TrainLabel, TestFeat, TestLabel)
# Out:
# Model accuracy on training:  0.8089887640449438
# Model accuracy on test:  0.7877094972067039

# %% [markdown]
# Using Principal Components as features not effective for logistic regression

# %%
# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
ParamGrid = {'penalty':['l1','l2','elasticnet'], 'fit_intercept':[True,False], 'l1_ratio':np.linspace(0,1,11)}
LogReg_Grid = GridSearchCV(LogReg, ParamGrid, cv=5, verbose=True)
LogReg_Grid.fit(TrainFeat[Features], TrainLabel['Survived'].ravel())
LogReg_Grid.best_params_
# Out:
# Fitting 5 folds for each of 66 candidates, totalling 330 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\tanth\Anaconda3\envs\maclearning\lib\site-packages\sklearn\linear_model\logistic.py:1506: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\tanth\Anaconda3\envs\maclearning\lib\site-packages\sklearn\linear_model\logistic.py:1506: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\tanth\Anaconda3\envs\maclearning\lib\site-packages\sklearn\linear_model\logistic.py:1506: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# ...

# %%
PredictionResults(LogReg_Grid, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.8075842696629213
# Model accuracy on test:  0.7877094972067039

# %%
FeatImportance = abs(LogReg_Grid.best_estimator_.coef_[0])*TrainFeat[Features].std().values
FeatImportanceDF = pd.DataFrame(data={'Features':TrainFeat[Features].columns, 'Importance':FeatImportance})
FeatImportanceDF.sort_values('Importance', ascending=False)
# Out:
#    Features  Importance
# 0  IsFemale    1.266315
# 1    Pclass    0.898164
# 4       Age    0.456280
# 5     SibSp    0.417273
# 2      Fare    0.117805
# 3     Parch    0.056000

# %% [markdown]
# ### Decision Tree

# %%
# Try a decision tree classifier
from sklearn.tree import DecisionTreeClassifier
DTree = DecisionTreeClassifier(max_depth=None, min_samples_leaf=20)
Features = ['IsFemale', 'Pclass', 'Fare', 'Parch', 'Age', 'SibSp']
DTree.fit(TrainFeat[Features], TrainLabel)
dot_data = sklearn.tree.export_graphviz(DTree, out_file=None, 
                      feature_names=Features,  
                      class_names=['Fatality','Survivor'],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
PredictionResults(DTree, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.8286516853932584
# Model accuracy on test:  0.7541899441340782

# %% [markdown]
# Let's try adding Principal Components as features

# %%
# Try decision tree with Principal Components
DTree_PCA = sklearn.tree.DecisionTreeClassifier(max_depth=None, min_samples_leaf=15)
Features_PCA = ['IsFemale', 'Pclass', 'Fare', 'Parch', 'Age', 'SibSp', 'PC3', 'PC1', 'PC2']
DTree_PCA.fit(TrainFeat[Features_PCA], TrainLabel)
dot_data = sklearn.tree.export_graphviz(DTree_PCA, out_file=None, 
                      feature_names=Features_PCA,  
                      class_names=['Fatality','Survivor'],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
PredictionResults(DTree_PCA, TrainFeat[Features_PCA], TrainLabel, TestFeat[Features_PCA], TestLabel)
# Out:
# Model accuracy on training:  0.8356741573033708
# Model accuracy on test:  0.7988826815642458

# %%
# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
param_grid = {'max_leaf_nodes': [None] + list(range(10,50)), 'min_samples_leaf':list(range(1,10))}
DTree_PCA_grid = GridSearchCV(DTree_PCA, param_grid, cv=5, verbose=True, n_jobs=4)
DTree_PCA_grid.fit(TrainFeat, TrainLabel)
DTree_PCA_grid.best_params_
# Out:
# Fitting 5 folds for each of 369 candidates, totalling 1845 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 1845 out of 1845 | elapsed:    2.8s finished
# {'max_leaf_nodes': 39, 'min_samples_leaf': 1}

# %%
PredictionResults(DTree_PCA_grid, TrainFeat, TrainLabel, TestFeat, TestLabel)
# Out:
# Model accuracy on training:  0.9058988764044944
# Model accuracy on test:  0.7988826815642458

# %% [markdown]
# ### Random Forest Classifiers

# %%
# Exclude PCA features
from sklearn.ensemble import RandomForestClassifier
Features = ['IsFemale', 'Pclass', 'Fare', 'Parch', 'Age', 'SibSp']
RF = RandomForestClassifier(n_estimators=100, 
                            max_features='sqrt', 
                            max_leaf_nodes=None, 
                            min_samples_leaf=5, 
                            min_samples_split=5,
                            max_depth=None)
RF.fit(TrainFeat[Features], TrainLabel['Survived'].ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
PredictionResults(RF, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.8707865168539326
# Model accuracy on test:  0.7877094972067039

# %%
# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV 
param_grid = {'bootstrap': [True],
              'max_depth': list(range(10,100,10)) + [None],
              'max_features': ['sqrt'],
              'max_leaf_nodes': [None],
              'min_samples_leaf': range(1,10,1),
              'min_samples_split': range(2,10,1),
              'n_estimators': [100]
             }
RF_grid = RandomizedSearchCV(RF, param_grid, cv=3, verbose=True, n_jobs=4, n_iter=400)
RF_grid.fit(TrainFeat[Features], TrainLabel['Survived'])
RF_grid.best_params_
# Out:
# Fitting 3 folds for each of 400 candidates, totalling 1200 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=4)]: Done 1200 out of 1200 | elapsed:  1.1min finished
# {'n_estimators': 100,
#  'min_samples_split': 5,
#  'min_samples_leaf': 5,
#  'max_leaf_nodes': None,
#  'max_features': 'sqrt',
#  'max_depth': 80,
#  'bootstrap': True}

# %%
PredictionResults(RF_grid, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.8792134831460674
# Model accuracy on test:  0.7932960893854749

# %%
# Let's use all the features
from sklearn.ensemble import RandomForestClassifier
RF_PCA = RandomForestClassifier(n_estimators=100, 
                                max_features='sqrt', 
                                max_leaf_nodes=None, 
                                min_samples_leaf=5, 
                                min_samples_split=5,
                                max_depth=None)
RF_PCA.fit(TrainFeat, TrainLabel['Survived'].ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
PredictionResults(RF_PCA, TrainFeat, TrainLabel, TestFeat, TestLabel)
# Out:
# Model accuracy on training:  0.875
# Model accuracy on test:  0.7541899441340782

# %%
# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV 
param_grid = {'bootstrap': [True],
              'max_depth': list(range(10,100,10)) + [None],
              'max_features': ['sqrt'],
              'max_leaf_nodes': [None],
              'min_samples_leaf': range(1,10,1),
              'min_samples_split': range(2,10,1),
              'n_estimators': [100]
             }
RF_PCA_grid = RandomizedSearchCV(RF_PCA, param_grid, cv=3, verbose=True, n_jobs=4, n_iter=400)
RF_PCA_grid.fit(TrainFeat, TrainLabel['Survived'])
RF_PCA_grid.best_params_
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=4)]: Done 600 out of 600 | elapsed:   42.6s finished
# {'n_estimators': 100,
#  'min_samples_split': 8,
#  'min_samples_leaf': 4,
#  'max_leaf_nodes': None,
#  'max_features': 'sqrt',
#  'max_depth': 70,
#  'bootstrap': True}

# %%
PredictionResults(RF_PCA, TrainFeat, TrainLabel, TestFeat, TestLabel)
# Out:
# Model accuracy on training:  0.875
# Model accuracy on test:  0.7541899441340782

# %% [markdown]
# Random forest seems to perform better without using PCs as features

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
Features = ['IsFemale', 'Pclass', 'Fare', 'Parch', 'Age', 'SibSp']
XG_Model = xgb.XGBClassifier(eta=0.1, 
                             max_depth=5,
                             subsample=0.5,
                             objective='binary:logistic',
                             eval_metric='auc',
                             num_class=1
                            )
XG_Model.fit(TrainFeat[Features], TrainLabel)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eta=0.1,
#               eval_metric='auc', gamma=0, learning_rate=0.1, max_delta_step=0,
#               max_depth=5, min_child_weight=1, missing=None, n_estimators=100,
#               n_jobs=1, nthread=None, num_class=1, objective='binary:logistic',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=None, silent=None, subsample=0.5, verbosity=1)

# %%
PredictionResults(XG_Model, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.9058988764044944
# Model accuracy on test:  0.7988826815642458

# %%
param_grid = {"eta": np.linspace(0.1, 0.5, 10),
              "max_depth": range(2,10),
              "min_child_weight": [1, 3, 5, 7],
              "gamma": np.linspace(0, 0.5, 1),
              "subsample": np.linspace(0.25, 1, 4),
              "colsample_bytree": np.linspace(0.25, 1, 4)
             }

XG_Model_grid = GridSearchCV(XG_Model, param_grid, n_jobs=4, cv=5, verbose=True)
XG_Model_grid.fit(TrainFeat[Features], TrainLabel['Survived'])
XG_Model_grid.best_params_
# Out:
# Fitting 5 folds for each of 5120 candidates, totalling 25600 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=4)]: Done 655 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=4)]: Done 1655 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=4)]: Done 3055 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 4855 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=4)]: Done 7055 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=4)]: Done 9655 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=4)]: Done 12655 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=4)]: Done 16055 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=4)]: Done 19855 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=4)]: Done 24055 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=4)]: Done 25600 out of 25600 | elapsed: 10.9min finished
# {'colsample_bytree': 1.0,
#  'eta': 0.1,
#  'gamma': 0.0,
# ...

# %%
PredictionResults(XG_Model_grid, TrainFeat[Features], TrainLabel, TestFeat[Features], TestLabel)
# Out:
# Model accuracy on training:  0.9241573033707865
# Model accuracy on test:  0.770949720670391
